# %%
import os

import numpy as np

import pandas as pd
pd.set_option('display.max_rows', 23)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 37)


import re

# %%
df = pd.read_csv(os.path.join('datasets', 'dataset-06-storms.csv.gz'))
# Out:
# C:\Users\Fidel\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
df_2 = df.loc[:, pd.notnull(df).sum()>len(df)*.8]

# %%
df_2.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# COUNTY_END         0
# END_RANGE          0
# LENGTH             0
# WIDTH              0
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# CROPDMG            0
# WFO           142069
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REFNUM             0
# dtype: int64

# %%
df_2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
df_3 = df[['EVTYPE','FATALITIES','INJURIES','PROPDMG','CROPDMG','PROPDMGEXP','CROPDMGEXP']]

# %%
def is_in_it(evtype):
    return "ORN" in evtype

# %%
evtypes = pd.Series(df_3.EVTYPE.unique())

#evtypes[evtypes.apply(lambda evtype: "ORN" in evtype)]
# el lambda es lo que va adentro en la formula de arriba

# %%
df_4 = df_3[(df_3['FATALITIES'] != 0) & (df_3['INJURIES'] != 0) & (df_3['CROPDMG'] != 0) & (df_3['PROPDMGEXP'] != 0)]

# %%
df_4
# Out:
#                          EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG  \
# 187909                  TORNADO         6.0     130.0      5.0      5.0
# 188604                  TORNADO        22.0     150.0    500.0     50.0
# 191344             WINTER STORM         3.0       5.0      5.0      5.0
# 192360  WINTER STORM HIGH WINDS         1.0      15.0     60.0      5.0
# 192371            WINTER STORMS        10.0      17.0    500.0    500.0
# 195016    TROPICAL STORM GORDON         8.0      43.0    500.0    500.0
# 196704                    FLOOD         5.0       5.0    500.0      5.0
# 196827                 BLIZZARD         8.0      15.0    500.0     50.0
# 196832       THUNDERSTORM WINDS         8.0       7.0     75.0     50.0
# 196834                 BLIZZARD         5.0     385.0     50.0     50.0
# 196835               HIGH WINDS         2.0      20.0     50.0    500.0
# ...                         ...         ...       ...      ...      ...
# ...

# %%
evtypes = pd.Series(df_4.EVTYPE.unique())
evtypes
# Out:
# 0                     TORNADO
# 1                WINTER STORM
# 2     WINTER STORM HIGH WINDS
# 3               WINTER STORMS
# 4       TROPICAL STORM GORDON
# 5                       FLOOD
# 6                    BLIZZARD
# 7          THUNDERSTORM WINDS
# 8                  HIGH WINDS
# 9                 FLASH FLOOD
# 10                       HEAT
#                ...
# 13                  HEAT WAVE
# 14                  HIGH WIND
# 15             TROPICAL STORM
# 16                  HURRICANE
# 17                  TSTM WIND
# 18                 HEAVY SNOW
# 19                   WILDFIRE
# 20          HURRICANE/TYPHOON
# 21             EXCESSIVE HEAT
# 22          THUNDERSTORM WIND
# 23                    TSUNAMI
# dtype: object

# %%
df_4.isnull().sum()
# Out:
# EVTYPE        0
# FATALITIES    0
# INJURIES      0
# PROPDMG       0
# CROPDMG       0
# PROPDMGEXP    4
# CROPDMGEXP    0
# dtype: int64
